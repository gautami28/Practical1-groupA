# %% [markdown]
# <a href="https://colab.research.google.com/github/gautami28/Practical1-groupA/blob/main/Practical1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
groupA = []
groupB = []
groupC = []


def cricket():
  n =  int(input("enter the totalnumber of students for cricket:"))
  for i in range(n):
    x= input("enter students roll number:")
    groupA.append(x)
  print(groupA)

def badminton():
  n =  int(input("enter the totalnumber of students for badminton:"))
  for i in range(n):
    x= input("enter students roll number:")
    groupB.append(x)
  print(groupB)

def football():
  n =  int(input("enter the totalnumber of students for football:"))
  for i in range(n):
    x= input("enter students roll number:")
    groupC.append(x)
  print(groupC)

cricket()
badminton()
football()

def intersection(groupA,groupB):
    groupR=[]
    for i in groupA:
        if i in groupB:
            groupR.append(i)
    return groupR

#print(f"intersection{intersection(groupA,groupB)}")

def diff(groupA,groupB):
  groupQ=[]
  for i in groupA:
    if i not in groupB:
      groupQ.append(i)
  return groupQ

#print(f"difference{diff(groupA,groupB)}")

def union(groupA,groupB):
    groupT=groupA.copy()
    for i in groupB:
        if i not in groupT:
            groupT.append(i)
    return groupT

#print(f"union{union(groupA,groupB)}")

def symmetric(groupA,groupB):
    groupS=[]
    D1=diff(groupA,groupB)
    print("Difference between Cricket and Badminton is : ", D1)
    D2=diff(groupB,groupA)
    print("Difference between Badminton and Cricket is : ", D2)
    groupS=union(D1,D2)
    return groupS

#print(f"difference{symmetric(groupA,groupB)}")


def Cri_Bad(groupA,groupB):
    groupV=intersection(groupA,groupB)
    print("List of students who play both cricket and badminton is : ", groupV)
    return len(groupV)

def cri_or_bad(groupA,groupB):
    groupN=symmetric(groupA,groupB)
    print("List of students who play either cricket or badminton but not both is : ",groupN)
    return len(groupN)

def Cri_nor_Bad(groupA,groupB,groupC):
    groupX = diff(groupA,union(groupB,groupC))
    print("List of students who play neither cricket nor badminton is : ",groupX)
    return len(groupX)

def Cri_and_Foot_not_Bad(groupA,groupB,groupC):
    groupZ=diff(intersection(groupA,groupB),groupC)
    print("List of students who play cricket and football but not badminton is : ",groupZ)
    return len(groupZ)

def main():  
  print("1. List of students who play both cricket and badminton")
  print("2. List of students who play either cricket or badminton but not both")
  print("3. List of students who play neither cricket nor badminton")
  print("4. Number of students who play cricket and football but not badminton")
  print("5. Exit\n")
  
  while input("do you want to continue enter Y to continue:") =="Y":
    ch=int(input("Enter your Choice :"))
    if ch==1:
      Cri_Bad(groupA,groupB)
    if ch==2:
      cri_or_bad(groupA,groupB)
    if ch==3:
      Cri_nor_Bad(groupA,groupB,groupC)
    if ch==4:
      Cri_and_Foot_not_Bad(groupA,groupB,groupC)
    if ch==5:
      break


main()
# Out:
# enter the totalnumber of students for cricket:3
# enter students roll number:55
# enter students roll number:22
# enter students roll number:44
# ['55', '22', '44']
# enter the totalnumber of students for badminton:4
# enter students roll number:55
# enter students roll number:66
# enter students roll number:31
# enter students roll number:44
# ['55', '66', '31', '44']
# enter the totalnumber of students for football:4
# enter students roll number:78
# enter students roll number:55
# enter students roll number:31
# enter students roll number:44
# ['78', '55', '31', '44']
# 1. List of students who play both cricket and badminton
# 2. List of students who play either cricket or badminton but not both
# 3. List of students who play neither cricket nor badminton
# 4. Number of students who play cricket and football but not badminton
# 5. Exit
#
# do you want to continue enter Y to continue:Y
# Enter your Choice :1
# List of students who play both cricket and badminton is :  ['55', '44']
# do you want to continue enter Y to continue:Y
# Enter your Choice :2
# Difference between Cricket and Badminton is :  ['22']
# Difference between Badminton and Cricket is :  ['66', '31']
# List of students who play either cricket or badminton but not both is :  ['22', '66', '31']
# do you want to continue enter Y to continue:Y
# Enter your Choice :4
# List of students who play cricket and football but not badminton is :  []
# do you want to continue enter Y to continue:Y
# Enter your Choice :3
# List of students who play neither cricket nor badminton is :  ['22']
# do you want to continue enter Y to continue:Y
# Enter your Choice :2
# Difference between Cricket and Badminton is :  ['22']
# Difference between Badminton and Cricket is :  ['66', '31']
# List of students who play either cricket or badminton but not both is :  ['22', '66', '31']
# do you want to continue enter Y to continue:N
